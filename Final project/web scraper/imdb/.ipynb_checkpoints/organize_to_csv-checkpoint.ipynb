# %%
import pdb
import re
import json
import cPickle as pickle
import pandas

# %%
def remove_non_ascii(s):
    # eg: u'Avatar\xa0' ---> u'Avatar'
    return re.sub(r'[^\x00-\x7F]+','', s)

# %%
with open("info_imdb.json", "r") as f:
    data= json.load(f)

# %%
with open("fb_like.json", "r") as f:
    fb= json.load(f)

# %%
a={1:2}
a.values()[0]
# Out:
# 2

# %%
fb_dict={}
for item in fb:
    fb_dict[item.values()[0]]
# Out:
# [{u'Columbus Short': u'1.2K'},
#  {u'Frank DiLeo': u'16'},
#  {u'Marianna Hill': u'54'},
#  {u'Year One': u'2.7K'},
#  {u'[Rec] 2': u'4K'},
#  {u'Dylan Sprouse': u'715'},
#  {u'Ben Piazza': u'4'},
#  {u'Valiant': u'542'},
#  {u'Achyut Potdar': u'3'},
#  {u'Kaitlyn Leeb': u'261'},
#  {u'Doomsday': u'3.6K'},
#  {u'Tommy Oliver': u'66'},
#  {u'Stephen Sowan': u'5'},
#  {u'Mark Pawson': u'5'},
#  {u'Molly Dunsworth': u'104'},
#  {u'Kent Faulcon': u'52'},
#  {u'David Cross': u'1.3K'},
#  {u'Capitalism: A Love Story': u'10K'},
#  {u'F\xe9lix Moati': u'8'},
#  {u'Claudia Karvan': u'149'},
#  {u'Joanna Cassidy': u'322'},
#  {u'Pauline Whyman': u'2'},
#  {u'Red Sky': u'445'},
#  {u'Sam Witwer': u'1.9K'},
#  {u'Brandon Spink': u'184'},
#  {u'Carl Duering': u'3'},
#  {u'Exorcist: The Beginning': u'910'},
#  {u'Jeffrey Falcon': u'33'},
#  {u'Julie Harris': u'364'},
#  {u'Manish Dayal': u'820'},
#  {u'Kim Ostrenko': u'7'},
#  {u'Ryan Murphy': u'711'},
#  {u'Linda Hunt': u'1.7K'},
# ...

# %%
data_df=pandas.DataFrame(columns=['movie_title','movie_imdb_link','movie_facebook_likes','director_name','director_facebook_likes','actor_1_name','actor_1_facebook_likes','actor_2_name','actor_2_facebook_likes','actor_3_name','actor_3_facebook_likes','cast_total_facebook_likes'])
count=0
for movie in data:
    row=[]
    row.append(remove_non_ascii(movie['movie_title']))
    row.append(moive['movie_imdb_link'])
    for item in fb:
        if 
    row.append(f)
